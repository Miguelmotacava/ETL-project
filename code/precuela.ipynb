# %%
#codigo proyecto

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd
import selenium 
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time

import warnings
warnings.filterwarnings('ignore')

# %%
#play_station
n=1
url = f'https://www.futbin.com/22/players?page={n}'
PATH=ChromeDriverManager().install()   
driver=webdriver.Chrome(PATH) 
driver.get(url)

html = req.get(url).text
soup=bs(html, 'html.parser')
try:
    acept = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/button[2]')
    acept.click()
except:
    pass

jogadores = driver.find_elements(By.TAG_NAME, 'tr')
stats = [jogadores[i].text.strip() for i in range(3,len(jogadores))]
stats_player = [] 
for i in range(len(stats)):
    a = stats[1].find(' ')
    stats[i] = stats[i].replace('\n',' ')
    stats[i] =stats[i].replace('\\','')
    stats[i] = stats[i].replace("\'",'')
    stats_player.append(stats[i])
st_pl = [i.split() for i in stats_player]

#names
names = driver.find_elements(By.CLASS_NAME, 'player_name_players_table.get-tp')
names_players = [i.text for i in names]

#datos num
datos_num = []
for i in range(len(st_pl)):
    tmp =[]
    for j in range(len(st_pl[i])):
        if st_pl[i][j].isnumeric() or st_pl[i][j].startswith('-'):
            tmp.append(st_pl[i][j])
    datos_num.append(tmp)

# medias
medias = [datos_num[i][0] for i in range(len(datos_num))]

# pos
pos = driver.find_elements(By.CLASS_NAME, 'font-weight-bold')
pos_player = [pos[i].text for i in range(7,len(pos)-4,2)]

# tipo
tipo = driver.find_elements(By.CLASS_NAME, 'mobile-hide-table-col')
tipo_player = [tipo[i].text for i in range(1,len(tipo))]
driver.quit()

# precio
precio = [datos_num[i][0] for i in range(len(datos_num))]

# skill
skill = [datos_num[i][1] for i in range(len(datos_num))]

# weak foot
wf = [datos_num[i][2] for i in range(len(datos_num))]

# ritmo
ritmo = [datos_num[i][3] for i in range(len(datos_num))]

# shot
shot = [datos_num[i][4] for i in range(len(datos_num))]

# pass
pase = [datos_num[i][5] for i in range(len(datos_num))]

# dribbling
drib = [datos_num[i][6] for i in range(len(datos_num))]

# defense
defense = [datos_num[i][7] for i in range(len(datos_num))] 

# physic
phy = [datos_num[i][8] for i in range(len(datos_num))]

# popularity
pop = [datos_num[i][9] for i in range(len(datos_num))]
len(pop)

# base stats
base = [datos_num[i][10] for i in range(len(datos_num))]

# in game stats
igs = [datos_num[i][-1] for i in range(len(datos_num))]

#time
times = [time.asctime() for i in range(30)]

data = {'name_player':names_players, 'media':medias, 'posicion':pos_player, 'tipo':tipo_player, 'precio':precio, 'skill':skill, 'wf':wf, 'ritmo':ritmo, 'shot':shot, 'pas':pase, 'drib':drib, 'def':defense, 'phy':phy, 'popularity':pop, 'base stats':base, 'igs':igs, 'times': times}

dt = pd.DataFrame(data)

# %%
from funciones  import *

# %%
len(times)
# Out:
# 30

# %%
dt
# Out:
#                 name_player media posicion                 tipo precio skill  \
# 0                      Pelé    99      CAM         Icon Moments     99     5
# 1              Lionel Messi    99       CF        ShapeShifters     99     5
# 2         Cristiano Ronaldo    99       LW        ShapeShifters     99     5
# 3            Raphaël Varane    99       CB  Premium Futties SBC     99     2
# 4           Ousmane Dembélé    99       RW      Premium Futties     99     5
# 5             Mohamed Salah    99      CAM  Premium Futties SBC     99     5
# 6        Robert Lewandowski    99       ST   Player Moments SBC     99     4
# 7                      Pelé    98      CAM                 Icon     98     5
# 8        Robert Lewandowski    98       ST                 TOTY     98     4
# 9              Lionel Messi    98       RW                 TOTY     98     4
# 10           Diego Maradona    98      CAM         Icon Moments     98     5
# 11            Karim Benzema    98       CF                 TOTS     98     4
# 12             David Ginola    98       ST   Shapeshifters Hero     98     5
# 13            Franck Ribéry    98       LW        ShapeShifters     98     5
# 14              Gareth Bale    98       RM          Premium SBC     98     5
# 15               Abedi Pelé    98       LW   Shapeshifters Hero     98     5
# 16             N'Golo Kanté    98      CAM        ShapeShifters     98     5
# 17        Wissam Ben Yedder    98       ST      Premium Futties     98     5
# 18                Neymar Jr    98      CAM  Premium Futties SBC     98     5
# 19        Christian Eriksen    98       CM         ShowDown SBC     98     5
# 20           Erling Haaland    98       ST   Player Moments SBC     98     4
# 21               Sadio Mané    98       ST   Player Moments SBC     98     5
# 22           Diego Maradona    97      CAM                 Icon     97     5
# 23            Kylian Mbappé    97       ST                 TOTY     97     5
# 24  Luiz Frello Filho Jorge    97       CM                 TOTY     97     4
# 25               Rúben Dias    97       CB                 TOTY     97     2
# 26        Cristiano Ronaldo    97       ST                 TOTY     97     5
# 27                  Ronaldo    97       ST                 Icon     97     5
# 28          Zinedine Zidane    97      CAM                 Icon     97     5
# 29        Cristiano Ronaldo    97       ST                 TOTS     97     5
#
#    wf ritmo shot pas drib def phy popularity base stats   igs  \
# 0   4    96   97  96   97  62  79       2188        527  2563
# 1   4    95   98  99   99  42  78       3861        511  2485
# 2   4    99   99  90   97  50  92       4299        527  2549
# 3   3    96   61  80   83  99  98       2152        517  2378
# 4   5    99   96  94   99  49  79       1836        516  2488
# 5   5    99   99  96   99  54  88       2567        535  2578
# 6   5    97   99  90   98  52  98       2481        534  2584
# 7   4    95   96  93   96  60  76       1747        516  2513
# 8   4    93   98  87   95  50  95      14630        518  2500
# 9   4    93   97  98   99  40  76       3671        503  2451
# 10  4    93   94  95   98  42  78       1582        500  2446
# 11  5    95   98  90   98  47  87       5324        515  2479
# 12  5    98   96  95   97  63  92       1476        541  2608
# 13  5    96   95  97   99  46  81       3030        514  2481
# 14  4    99   98  97   97  70  96       7836        557  2684
# 15  5    98   93  96   99  64  75       1706        525  2557
# 16  4    92   93  92   96  92  91       1792        556  2651
# 17  5    99   99  93   99  55  85       2022        530  2582
# 18  5    99   95  94   99  44  73       4112        504  2467
# 19  5    96   97  99   98  90  92       2124        572  2751
# 20  5    99   99  91   95  54  98        693        536  2581
# 21  4    99   96  95   99  56  92        936        537  2586
# 22  3    92   93  92   97  40  76        910        490  2392
# 23  4    99   95  90   98  44  88      -9550        514  2457
# 24  4    88   90  98   93  86  87      -2846        542  2620
# 25  4    87   50  84   81  97  96       5981        495  2310
# 26  4    93   98  88   95  39  92       2978        505  2445
# 27  5    98   97  83   97  46  79       3702        500  2399
# 28  5    86   93  98   98  76  88       2032        539  2607
# 29  4    94   99  88   95  39  91       2760        506  2455
#
#                        times
# 0   Sun Sep  4 12:01:16 2022
# 1   Sun Sep  4 12:01:16 2022
# 2   Sun Sep  4 12:01:16 2022
# 3   Sun Sep  4 12:01:16 2022
# 4   Sun Sep  4 12:01:16 2022
# 5   Sun Sep  4 12:01:16 2022
# 6   Sun Sep  4 12:01:16 2022
# 7   Sun Sep  4 12:01:16 2022
# 8   Sun Sep  4 12:01:16 2022
# 9   Sun Sep  4 12:01:16 2022
# 10  Sun Sep  4 12:01:16 2022
# 11  Sun Sep  4 12:01:16 2022
# 12  Sun Sep  4 12:01:16 2022
# 13  Sun Sep  4 12:01:16 2022
# 14  Sun Sep  4 12:01:16 2022
# 15  Sun Sep  4 12:01:16 2022
# 16  Sun Sep  4 12:01:16 2022
# 17  Sun Sep  4 12:01:16 2022
# 18  Sun Sep  4 12:01:16 2022
# 19  Sun Sep  4 12:01:16 2022
# 20  Sun Sep  4 12:01:16 2022
# 21  Sun Sep  4 12:01:16 2022
# 22  Sun Sep  4 12:01:16 2022
# 23  Sun Sep  4 12:01:16 2022
# 24  Sun Sep  4 12:01:16 2022
# 25  Sun Sep  4 12:01:16 2022
# 26  Sun Sep  4 12:01:16 2022
# 27  Sun Sep  4 12:01:16 2022
# 28  Sun Sep  4 12:01:16 2022
# 29  Sun Sep  4 12:01:16 2022

# %%
"""#names
names = []
for i in range(len(st_pl)):
    if (st_pl[i][1].isnumeric() and st_pl[i][2].isnumeric()) or (st_pl[i][1].isnumeric()): 
        names.append(st_pl[i][0])
    elif st_pl[i][2].isnumeric(): 
        names.append(st_pl[i][0] + ' ' + st_pl[i][1] )
    else:
        names.append(st_pl[i][0] + ' ' + st_pl[i][1] + ' ' + st_pl[i][2] )


st_pl
len(names), len(st_pl[0])
names"""

# %%
"""for i in range(len(st_pl)):
    if (st_pl[i][1].isnumeric() and st_pl[i][2].isnumeric()) or (st_pl[i][1].isnumeric()): 
        st_pl[i].pop(0)
    elif st_pl[i][2].isnumeric(): 
        st_pl[i].pop(0)
        st_pl[i].pop(0)
    else:
        st_pl[i].pop(0)
        st_pl[i].pop(0)
        st_pl[i].pop(0)
st_pl[2]"""
