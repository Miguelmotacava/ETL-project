# %%
# primer escrapeo

# %%
from funciones import *

# %%
# %%time
df_final=pd.DataFrame()
i = 1
for i in range(1,101):
    try:
        print(f'iteración {i}')
        
        
        url = f'https://www.futbin.com/22/players?page={i}'
        var = data1(url)
        df_final = pd.concat([df_final,var], axis=0)
        print('finalizado')
        i = i + 1
    except:
        pass
    
    if i == 100:
        break
df_final=df_final.reset_index(drop = True)
# Out:
# iteración 1
# finalizado
# iteración 2
# finalizado
# iteración 3
# finalizado
# iteración 4
# finalizado
# iteración 5
# finalizado
# iteración 6
# finalizado
# iteración 7
# finalizado
# iteración 8
# finalizado
# iteración 9
# finalizado
# iteración 10
# finalizado
# iteración 11
# finalizado
# iteración 12
# finalizado
# iteración 13
# finalizado
# iteración 14
# finalizado
# iteración 15
# finalizado
# iteración 16
# finalizado
# iteración 17
# finalizado
# iteración 18
# finalizado
# iteración 19
# finalizado
# iteración 20
# finalizado
# iteración 21
# finalizado
# iteración 22
# finalizado
# iteración 23
# finalizado
# iteración 24
# finalizado
# iteración 25
# finalizado
# iteración 26
# finalizado
# iteración 27
# finalizado
# iteración 28
# finalizado
# iteración 29
# finalizado
# iteración 30
# finalizado
# iteración 31
# finalizado
# iteración 32
# finalizado
# iteración 33
# finalizado
# iteración 34
# finalizado
# iteración 35
# finalizado
# iteración 36
# finalizado
# ...

# %%
df_final.to_json('scrap_players.json', orient = 'records' )
scrap_players = df_final.to_csv('scrap_players.csv', sep =' ')

# %%
from pymongo import MongoClient
cursor = MongoClient("mongodb://localhost:27017")

# %%
db=cursor.Fifa22  #nueva base de datos

# %%
colec=db.players   # nueva coleccion

# %%
db.players.insert_many(df_final.to_dict('records'))

# %%
path = 'Fifa22_Player_Segmentation/Final_Table.csv'

# %%
playersgit = pd.read_csv(path)

# %%
# segundo escrapeo

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd
import selenium 
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time

import warnings
warnings.filterwarnings('ignore')

# %%
"""n=0
url = f'https://sofifa.com/players?offset={n}'
driver=webdriver.Chrome(PATH) 
driver.get(url)
html = req.get(url).text
soup=bs(html, 'html.parser')
try:
    acept = driver.find_element(By.XPATH, '/html/body/div[6]/div[1]/div[2]/div/div/div/div[5]/div[2]/a/span')
    acept.click()
except:
    pass
"""
# Out:
# "n=0\nurl = f'https://sofifa.com/players?offset={n}'\ndriver=webdriver.Chrome(PATH) \ndriver.get(url)\nhtml = req.get(url).text\nsoup=bs(html, 'html.parser')\ntry:\n    acept = driver.find_element(By.XPATH, '/html/body/div[6]/div[1]/div[2]/div/div/div/div[5]/div[2]/a/span')\n    acept.click()\nexcept:\n    pass\n"

# %%
"""players = driver.find_elements(By.CLASS_NAME, 'col-name')

a = [i.text for i in players]

pl = [players[i].text for i in range(2,len(players),2)]

names = [i for i in pl if i.isnumeric()==False] 

ts = [players[i].text.split('\n')[0] for i in range(3,len(players),2)]
"""
# Out:
# "players = driver.find_elements(By.CLASS_NAME, 'col-name')\n\na = [i.text for i in players]\n\npl = [players[i].text for i in range(2,len(players),2)]\n\nnames = [i for i in pl if i.isnumeric()==False] \n\nts = [players[i].text.split('\n')[0] for i in range(3,len(players),2)]\n"

# %%
# %%time
df_final2=pd.DataFrame()
i = 1
for n in range(0,6001,60):
    try:
        print(f'iteración {1}')
        url = f'https://sofifa.com/players?offset={n}'
        var = data2(url)
        df_final2 = pd.concat([df_final2,var], axis=0)
        print('finalizado')
        i = i + 1
    except:
        pass
    
    if i == 6000:
        break
df_final2=df_final2.reset_index(drop = True)
# Out:
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# iteración 1
# finalizado
# ...

# %%
df_final2
# Out:
#                           names                      equipos
# 0              H. Badstuber\nCB                    FC Luzern
# 1                  K. Ayhan\nCB         U.S. Sassuolo Calcio
# 2                    Antony\nRW                         Ajax
# 3     16\n Mikel Arteta\nCM CDM                      Arsenal
# 4          21\n Diego Costa\nST           Atlético de Madrid
# ...                         ...                          ...
# 5995       M. Szwoch\nCAM CM RM                  Wisła Płock
# 5996   Pedro Chirivella\nCDM CM                    FC Nantes
# 5997       15\n L. Hurst\nRM CM             Cambridge United
# 5998       D. Blanco\nCM CDM RM  Club Atlético Independiente
# 5999          E. Aguirre\nLB RB                 CF Monterrey
#
# [6000 rows x 2 columns]

# %%
scrap_players2 = df_final2.to_csv('scrap_players2.csv', sep =' ')
